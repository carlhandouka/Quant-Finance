# %%
import numpy as np

# %%
def forward_prices_arbitrage(F0,S0,r,T,short_selling: bool): 
    if short_selling== True:
        if F0> S0*np.exp(r*T):
            print('buy the asset and short the forward on the asset, profit:', F0 - S0*np.exp(r*T))
        elif F0< S0*np.exp(r*T):
            print('short the asset and long the forward contract on it, profit:', S0*np.exp(r*T)-F0)
    else:
